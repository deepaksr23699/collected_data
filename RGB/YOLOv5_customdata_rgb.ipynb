# %%
import os

# %% [markdown]
# Organize dataset

# %%
# Define paths to the train, val, and test directories
train_images_dir = '/content/annotations-1/train/images'
val_images_dir = '/content/annotations-1/valid/images'
test_images_dir = '/content/annotations-1/test/images'

# Path where you want to save your dataset.yaml file
yaml_file_path = '/content/annotations-1/data.yaml'

# Number of classes and their names
num_classes = 2
class_names = ['Person', 'Vehicle4W']

# Create the YAML file content
yaml_content = f"""
# Paths to the training and validation datasets
train: {train_images_dir}
val: {val_images_dir}

# Optional: Path to the test dataset (if you have one)
test: {test_images_dir}

# Number of classes
nc: {num_classes}

# Class names
names: {class_names}
"""

# Write the content to the dataset.yaml file
with open(yaml_file_path, 'w') as yaml_file:
    yaml_file.write(yaml_content)

print(f'dataset.yaml created at: {yaml_file_path}')
# Out:
# dataset.yaml created at: /content/annotations-1/data.yaml

# %%
# Path to YAML file
yaml_file_path = '/content/annotations-1/data.yaml'

# Read and print the contents of the YAML file
with open(yaml_file_path, 'r') as yaml_file:
    yaml_contents = yaml_file.read()

print("Contents of the YAML file:")
print(yaml_contents)
# Out:
# Contents of the YAML file:
#
# # Paths to the training and validation datasets
# train: /content/annotations-1/train/images
# val: /content/annotations-1/valid/images
#
# # Optional: Path to the test dataset (if you have one)
# test: /content/annotations-1/test/images
#
# # Number of classes
# nc: 2
#
# # Class names
# names: ['Person', 'Vehicle4W']

# %% [markdown]
# Install Requirements & Download pretrained model

# %%
# Install necessary packages
# %pip install -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt

# %%
# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17080, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 17080 (delta 21), reused 7 (delta 7), pack-reused 17050 (from 3)
# Receiving objects: 100% (17080/17080), 15.69 MiB | 17.16 MiB/s, done.
# Resolving deltas: 100% (11726/11726), done.
# /content/yolov5

# %% [markdown]
# Finetune YOLOv5

# %%
img_size = 640  # Image size
batch_size = 32  # Batch size
epochs = 25  # Number of epochs
data_yaml_path = '/content/annotations-1/data.yaml'  # Path to your dataset YAML file
weights = 'yolov5s.pt'  # Pre-trained weights
device = '0'

# !python train.py --img {img_size} --batch {batch_size} --epochs {epochs} --data {data_yaml_path} --weights {weights} --device {device}
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-12-31 03:43:38.019612: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-31 03:43:38.053773: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-31 03:43:38.064747: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# ...

# %% [markdown]
# Testing

# %%
# !python val.py --data {data_yaml_path} --weights "/content/yolov5/runs/train/exp2/weights/best.pt" --img {img_size} --batch {batch_size} --task test
# Out:
# val: data=/content/annotations-1/data.yaml, weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-390-g0797106a Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/annotations-1/test/labels... 390 images, 47 backgrounds, 0 corrupt: 100% 390/390 [00:00<00:00, 575.42it/s]
# test: New cache created: /content/annotations-1/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 13/13 [00:06<00:00,  2.03it/s]
#                    all        390        343      0.996          1      0.992      0.876
# ...

# %%
# !python val.py --data {data_yaml_path} --weights "/content/yolov5/runs/train/exp2/weights/best.pt" --img {img_size} --save-json
# Out:
# val: data=/content/annotations-1/data.yaml, weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-390-g0797106a Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/annotations-1/valid/labels.cache... 346 images, 34 backgrounds, 0 corrupt: 100% 346/346 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 11/11 [00:05<00:00,  1.88it/s]
#                    all        346        312      0.993          1      0.991      0.875
# ...
